# %% [markdown]
# # Definindo funções
# O esqueleto básico das função no R é demonstrado abaixo:

# %%
def nome_função(): # def(keyword) define a função
    return # return(statement) retorna o valor da função

# %% [markdown]
# Função da soma de dois argumentos

# %%
def soma(a,b):
    return (a + b)

# %%
soma(1,1)
# Out:
# 2

# %%
help(def)
# Out:
#   Cell In[5], line 1
#     help(def)
#          ^
# SyntaxError: invalid syntax

# %%
x = 1
def f():
    return x

# %%
print(x)
# Out:
# 1

# %%
print(f())
# Out:
# 1

# %%
x = 1
def f():
    x = 2
    return x

# %%
print(x)
print(f())
print(x)
# Out:
# 1
# 2
# 1

# %%
x = 0
y = 0
def incr(x):
    y = x + 1
    return y

# %%
incr(5)
# Out:
# 6

# %%
print(x,y)
# Out:
# 0 0

# %%
numcalls = 0
def square(x):
    global numcalls
    numcalls = numcalls +1
    return x * x

# %%
square(2)
# Out:
# 4

# %%
square(4)
# Out:
# 16

# %%
def count_digits(x):
    return len(str(x))

# %%
count_digits(251)
# Out:
# 3

# %%
def istrcmp(x,y):
    return x.upper() == y.upper()

# %%
istrcmp("Python","PYthon")
# Out:
# True

# %%
x = "python"
x.upper()
# Out:
# 'PYTHON'
