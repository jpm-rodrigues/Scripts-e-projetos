# %% [markdown]
# #Curso de Introdução ao Python.

# %% [markdown]
# ##Operações matemáticas básicas

# %%
# operação de calculadora
2+2
# Out:
# 4

# %%
5-2
# Out:
# 3

# %%
10*5
# Out:
# 50

# %%
10/2
# Out:
# 5.0

# %%
7/2
# Out:
# 3.5

# %%
7//2
#usar duas barras para dar uma divisão inteira
# Out:
# 3

# %%
7%2
#usar '%' para obter o resto
# Out:
# 1

# %%
1.5 ** 12
#usar 2 asteriscos (**) para usar potência
# Out:
# 129.746337890625

# %% [markdown]
# ***

# %%
# utilizando objetos nas operações
x = 5
y = 10

resultado = x * y

# %%
resultado
# Out:
# 50

# %%
print(resultado)
# Out:
# 50

# %%
print(resultado * x)
# Out:
# 250

# %%
print("O resultado da multiplicação de x e y é resultado")
# Out:
# O resultado da multiplicação de x e y é resultado

# %%
print("O resultado da multiplicação de x e y é {}" .format(resultado))
# Out:
# O resultado da multiplicação de x e y é 50

# %%
print("O resultado da multiplicação de {} e {} é {}" .format(x,y, resultado))
# Out:
# O resultado da multiplicação de 5 e 10 é 50

# %% [markdown]
# Se mudar os objetos e correr de novo os códigos será utilizado o código mais recente

# %% [markdown]
# ***
# ## Tipos de valores:
#
# * int: valores inteiros
# * float: valores com casas decimais
# * string (str): texto
# * bool: valores lógicos, True or False

# %%
inteiro = 10
type(inteiro)
# Out:
# int

# %%
decimal = 1.5
type(decimal)
# Out:
# float

# %%
texto = "Parminho"
type(texto)
# Out:
# str

# %%
a = 5
b = 3

a == b #Um igual é atribuição de valor, dois iguais é uma comparação
# Out:
# False

# %%
comparação = a==b
type(comparação)
# Out:
# bool

# %% [markdown]
# Outras operações
#
# * **==**: igual a.
# * **!=**: diferente de.
# * **>**: maior que.
# * **<**: menor que.
# * **>=**: maior ou igual,
# * **<=**: menor ou igual.

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %% [markdown]
# ***

# %% [markdown]
# ## Estruturas de dados

# %%
# Listas []
lista = [1,4,5,8,9]

# %%
type(lista)
# Out:
# list

# %%
#selecionar o primeiro valor da lista
lista[0]
# Out:
# 1

# %%
#selecionar o segundo valor da lista
lista[1]
# Out:
# 4

# %%
#selecionar o último valor da lista
lista[-1]
# Out:
# 9

# %%
#retornar o número de objetos na lista - função len 
len(lista)
# Out:
# 5

# %%
#acrescentar um valor à lista - função append
lista.append(21)
lista
# Out:
# [1, 4, 5, 8, 9, 13, 13, 21]

# %%
#excluir o valor de uma lista - função pop
lista.pop(-2)
# Out:
# 13

# %%
lista
# Out:
# [1, 4, 5, 8, 9, 13, 21]

# %%
#caso não especificado, exclui o último número
lista.pop()
# Out:
# 21

# %%
lista
# Out:
# [1, 4, 5, 8, 9, 13]

# %%
#Criando outra lista
Lista2 = ['Parminho','Biribinhas','Rudney','Parminho']
Lista2
# Out:
# ['Parminho', 'Biribinhas', 'Rudney', 'Parminho']

# %%
Lista2.remove('Rudney')

# %%
Lista2
# Out:
# ['Parminho', 'Biribinhas', 'Parminho']

# %%
Lista2.remove('Parminho')
Lista2
# Out:
# ['Biribinhas', 'Parminho']

# %%
Lista2.clear()

# %%
Lista2
# Out:
# []

# %%
Lista_estados = ['Minas Gerais', 'São Paulo', 'Rio de Janeiro']
Lista_estados
# Out:
# ['Minas Gerais', 'São Paulo', 'Riode Janeiro']

# %%
Lista_estados[2] = 'Rio de Janeiro'
Lista_estados
# Out:
# ['Minas Gerais', 'São Paulo', 'Rio de Janeiro']

# %%
# estrutura de tupla
tupla = (2, 5, 7)
# tupla são objetos imutáveis, não sendo possível acrescentar ou remover valores

# %%
tupla
# Out:
# (2, 5, 7)

# %%
tupla[1]
# Out:
# 5

# %%
tupla.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c2e965c14a57> in <module>()
# ----> 1 tupla.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# estrutura dicionário
dicionario = {
    'Minas Gerais' : 31,
    'São Paulo': 35,
    'Rio de Janeiro': 33
}

# %%
dicionario
# Out:
# {'Minas Gerais': 31, 'Rio de Janeiro': 33, 'São Paulo': 35}

# %%
dicionario.keys()
# Out:
# dict_keys(['Minas Gerais', 'São Paulo', 'Rio de Janeiro'])

# %%
dicionario.values()
# Out:
# dict_values([31, 35, 33])

# %%
dicionario['Minas Gerais']
# Out:
# 31

# %%
dicionario['Espírito Santo'] = 32

# %%
dicionario
# Out:
# {'Espírito Santo': 32,
#  'Minas Gerais': 31,
#  'Rio de Janeiro': 33,
#  'São Paulo': 35}

# %%
dicionario.pop('Espírito Santo')
# Out:
# 32

# %%
dicionario
# Out:
# {'Minas Gerais': 31, 'Rio de Janeiro': 33, 'São Paulo': 35}

# %% [markdown]
# ***

# %% [markdown]
# ## Ajuda

# %%
## Ajuda
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
# ?list.pop
