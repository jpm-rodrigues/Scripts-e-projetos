# %%
import pandas as pd

# %%
# Importando o csv com o pacote panda
pd.read_csv("/home/jpmr/Desktop/como saber qual serviço é de qual lugar versão 2")
# Out:
# Traceback (most recent call last):
#   File "/home/jpmr/.vscode/extensions/ms-python.python-2025.0.0-linux-x64/python_files/python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
#   File "/home/jpmr/Python/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jpmr/Python/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jpmr/Python/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# # Criando o dicionário

# %% [markdown]
# organograma = {
#     "Diretoria Industrial": {di}
#     "Presidência": {}
#     "Diretoria do Instituto Otávio Magalhães": {}
#     "Diretoria de Planejamento Gestão e Finanças": {}
#     "Diretoria de Pesquisa e Desenvolvimento": {}
# }

# %%
# Divisões
di = {
    "DGQ - Divisão de Garantia da Qualidade": {
        "SGeQ - Serviço de Gestão da Qualidade": "1",
        "SAQ - Serviço de Avaliação da Qualidade": "2",
        "SVQ - Serviço de Validação e Qualificação": "3",     
        }
}

# Primeiramente defininindo as chaves diretorias, e os valores outros dicionários
organograma = {
    "Diretoria Industrial": di
}

organograma

# Inserindo as divisões
# Out:
# {'Diretoria Industrial': {'DGQ - Divisão de Garantia da Qualidade': {'SGeQ - Serviço de Gestão da Qualidade': '1',
#    'SAQ - Serviço de Avaliação da Qualidade': '2',
#    'SVQ - Serviço de Validação e Qualificação': '3'}}}

# %% [markdown]
# # Parte do programa mesmo

# %%
# Fazendo o rolê de ter que inserir algum input
serviço = str(input("Insira o nome do serviço: ")) # Definindo serviço como a string que vem depois do input prompt


# Aí o objeto serviço vai puxar pelo nome do serviço, a diretoria e a divisão
# Out:
# Insira o nome do serviço: SGamb
